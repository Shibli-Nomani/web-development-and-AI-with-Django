# %% [markdown]
# <h1 style="padding: 10px;
#               color:white;background-color: #5642C5;">
#            Assingnment-04
# </h1>

# %% [markdown]
# <p style="padding: 10px;
#               color:white;background-color: #5642C5;">👉
#            Google Drive Link for project file
# <a href="https://drive.google.com/file/d/1z23_ShlLD9iIZyqt2qB7jTKbQ5ZAQASx/view?usp=share_link target=" _blank"="" style="color:orange;" rel=" noreferrer nofollow"> Google Drive Link for project file </a>
#         </p>

# %% [markdown]
# <h3>link details</h3>
# https://drive.google.com/file/d/1z23_ShlLD9iIZyqt2qB7jTKbQ5ZAQASx/view?usp=share_link

# %% [markdown]
# <p style="padding: 10px;
#               color:white;background-color: #5642C5;">👉
#            create project and app
# </p>

# %% [markdown]
# 1. Create a project and app.
#
# 2. Print your name.
#
# N:B: You can use Django globally / inside virtual environment.

# %% [markdown]
# <p style="padding: 10px;
#               color:white;background-color: #5642C5;">👉
#            Install Python in PC
# </p>

# %% [markdown]
# <h2>Step-01- Download and Install Visual Studio for windows</h2>
#
#
# https://visualstudio.microsoft.com/

# %% [markdown]
# <p style="padding: 10px;
#               color:white;background-color: #5642C5;">👉
#            Need to install some extensions at visualstudio environment
# </p>

# %% [markdown]
# 1. Python : Since Django is heavly involved with Python related work. This will make easier to work with python in Visual Studio
# 2. Python Extension Pack: Generate Python DOC string
# 3. Auto Rename Tag: To avoid unwanted tagging error/missing tag such (`<h2>/</h2>`)
# 4. Prettier - Code formatter: exception error/code format handling
# 5. SQLite Viewer : By default Database. We can open this Database from here to see what is in the DB or Not. In addition, we can use database as well.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <h2>Step-02: Django Installation</h2>
#
# 1. **Globally :** Install using the PC Environment. It will always run on PC. Creating pressure on PC Unnecessarily
# 2. **Virtual Environment:** Only create Django enivornment inside the project using Visual Studio. PC remains free.

# %% [markdown]
# <p style="padding: 10px;
#               color:white;background-color: #5642C5;">👉
#            Note: most cases we use virtual environment. Here we are following the rapid/shortcut approach.
# </p>

# %% [markdown]
# <h2>Step-03: Create Directory using cmd[run as admin]from desktop</h2>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <h2>STEP-04: Create Django Project at Visual Studio Virtual Environment</h2>
#
# Alternatively, create directory from visual studio terminal and proceed further.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <h2>Step-05: Now Install Django inside virtual environment</h2>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <h2>Step-06: Create Project inside virtual environment</h2>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <h2>Step-07: Now we need to use the manage.py inside the project "myfirstProject001"</h2>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <p style="padding: 10px;
#               color:white;background-color: #5642C5;">👉
#            After enter into the provided link in a browser, we will get following response.
# </p>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <h2>Step-08: Create Apps</h2>
#
# **Project:** it's whole set of work.
#
#
# **Apps:** when we develope the project part by part/splitting(one or more Apps)
#
# 1. **Easy Error Rectification**
# 2. **Reusability**

# %% [markdown]
# <p style="padding: 10px;
#               color:white;background-color: #5642C5;">👉
#            Note: If we split the project into small portion, we can easily rectify the error for specific part and it can be reusable for any new project where similar types of work is requiered. These are the advantages.
# </p>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <h2>Step-09: Connect the Apps with main project(myfirstProject001)</h2>

# %% [markdown]
# <p style="padding: 10px;
#               color:white;background-color: #5642C5;">👉
#            Unless and until we connect the apps with main project. Apps remain meaningless.
# </p>

# %% [markdown]
# <h2>Stp-10: settings.py [go to project >> settings.py]</h2>
# some codes are bydefault inputed. we need to add required line only. After workdone, save the settings.py file.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <h2>Stp-11: views.py [go to project >> your apps >> views.py]</h2>
# some codes are bydefault inputed. we need to add required line only. After workdone, save the views.py file.

# %% [markdown]
# <p style="padding: 10px;
#               color:white;background-color: #5642C5;">👉
#           views.py can be created based on function based view or clas based view. Here we use function base view.
# </p>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <h2> Step-12: urls.py [go to project >> urls.py]</h2>
# some codes are bydefault inputed. we need to add required line only. After workdone, save the urls.py file. </h2>

# %% [markdown]
# <p style="padding: 10px;
#               color:white;background-color: #5642C5;">👉
#   To get the view of output, we must create url. And **we need to create the url inside main project.
# </p>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <h3>Important Nodes</h3>
# 1. save the settings.py file `[project area]`
# 2. save the views.py file `[apps area]`
# 3. save the url.py file `[project area]`
#
# Then run the manage server: (env) E:\Data Science\Django web Development  for AI\allDjangoWork\myfirstProject001>python manage.py runserver

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <p style="padding: 15px;
#               color:white;background-color: #16A085 ;">👉
#          Final Output of yourName web apps
# </p>

# %% [markdown]
# <h3>url link</h3>
#
# Go to the url and you will get the result
# http://127.0.0.1:8000/

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >

# %% [markdown]
# If you have any advice, please let me know.
