# %% [markdown]
# <h1 style="padding: 10px;
#               color:white;background-color: #5642C5;">
#            Assignment-05
# </h1>

# %% [markdown]
# <p style="padding: 10px;
#               color:white;background-color: #5642C5;">👉
#            Google Drive Link for project file
# <a href="https://drive.google.com/file/d/1ui5ovlM2WO3hoXQNiAHTxeEHYUztM8FY/view?usp=sharing" _blank"="" style="color:orange;" rel=" noreferrer nofollow"> Google Drive Link for project file </a>
#         </p>

# %% [markdown]
# <h3>link details</h3>
# https://drive.google.com/file/d/1ui5ovlM2WO3hoXQNiAHTxeEHYUztM8FY/view?usp=sharing

# %% [markdown]
# <p style="padding: 10px;
#               color:white;background-color: #5642C5;">👉
#            create project and app
# </p>

# %% [markdown]
# 1. Create a project.
# 2. Create minimum 3 apps inside project.
# 3. Use include() function.
# 4. Use render() function.
# 5. Create ‘templates’ folder & .html file for every apps.
#
# N:B: You will install Django inside virtual environment.

# %% [markdown]
# <p style="padding: 10px;
#               color:white;background-color: #5642C5;">👉
#            Google Drive Link for project file
# <a href="https://github.com/Shibli-Nomani/web-development-and-AI-with-Django/blob/main/class-05-create-django-project-and-apps/assignment_04.ipynb" _blank"="" style="color:orange;" rel=" noreferrer nofollow"> Google Drive Link for project file </a>
#         </p>

# %% [markdown]
# <h2>Step-02: settings.py [go to project >> settings.py]</h2>
#
# some codes are bydefault inputed. we need to add required line only. After workdone, save the settings.py file.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <h2> Step-03: Create Template </h2>
# every webiste has lot of details in one page. when we write all of them in a views.py, it will get messy and details identification will be quite harder. Here we can introduce TEMPLATE to avoid such issues.
#
# we create templates and under the templates, we ceate each folder for each apps to store the `.html` files

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <p style="padding: 10px;
#               color:white;background-color: #5642C5;">👉
#            now go to settings.py and connect the templates
# </p>

# %% [markdown]
# `# Build paths inside the project like this: BASE_DIR / 'subdir'.`
#
# `BASE_DIR = Path(__file__).resolve().parent.parent`
#
# `TEMPLATE_DIR = BASE_DIR / 'templates'`
#
# #only use TEMPLATE_DIR at DIRS section
#
# `TEMPLATES = [`
#
#    ` {`
#
#         `'BACKEND': 'django.template.backends.django.DjangoTemplates',`
#
#         `'DIRS': [TEMPLATE_DIR],`

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <h2>Step-04: views.py [go to project >> your apps >> views.py]</h2>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <h2>Step-05: create urls.py under the apps and urls.py [go to project >> your apps >> urls.py]</h2>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <p style="padding: 10px;
#               color:white;background-color: #5642C5;">👉
#            add to urls.py under project multiappsproject002(inner project)
# </p>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <p style="padding: 15px;
#               color:white;background-color: #16A085 ;">👉
#          Final Output of yourName web apps
# </p>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1.http://127.0.0.1:8000/
#
# 2.http://127.0.0.1:8000/fb/football/
#
# 3.http://127.0.0.1:8000/bk/basketball/

# %% [markdown]
# ![image.png](data:image/png;base64,...)
