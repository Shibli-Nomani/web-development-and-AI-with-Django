# %% [markdown]
# #Advance html
# Hyper Text Markup Language
# It's a structure of a website like as building structure, human structure

# %% [markdown]
# <p style="padding: 10px;
#               color:white;background-color: #5642C5;">👉
#            Google Drive Link for project file
# <a href="https://drive.google.com/file/d/1ppMny_nzRARQu6QsnY0dWRJuuCKV9RSY/view?usp=sharing" _blank"="" style="color:orange;" rel=" noreferrer nofollow"> Google Drive Link for project file </a>
#         </p>

# %% [markdown]
# <p style="padding: 10px;
#               color:white;background-color: #5642C5;">👉
#            How to work on settings.py, apps views.py, apps urls.py, apps urls.py, multiple apps, html templates
# <a href="https://github.com/Shibli-Nomani/web-development-and-AI-with-Django/blob/main/class-7-template-inherit-views-filter-tag/assigment_06.ipynb" _blank"="" style="color:orange;" rel=" noreferrer nofollow"> for details</a>
#         </p>

# %% [markdown]
# <p style="padding: 10px;
#               color:white;background-color: #5642C5;">👉
#            important commands
# </p>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <h1> Final Output: </h1>
# http://127.0.0.1:8000/cn/contacts

# %% [markdown]
# While migrating the projecct directory on different directory or pc, do perform as follows before `python manage.py runserver`

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# To call html built-in structure, using exclamatory sign : `!`. sometimes shortcut doesn't work. Then you need to follow below steps

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Headlines and Comment Process
# comment process: `<!-- Headings-->`
# It will not display in browser. It's used for future understanding

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <h2> Paragraph, Strong and Bold </h2>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Del and INS (old and current price)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <h2>Abbreviation</h2>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# sup and sub tag
#
# 1. sup: power
# 2. sub: half a character below

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Pre Tag
# Used for same positioning

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Span Tag:
#
# Add color on specific span

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # anchor and href (for hyperlink tag)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Ordered List
#
# for copy line: Shift + Alt + DownArrow

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Unorderd Tag List

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #create form

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Final Form

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Table

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# div tag
#
# <p> most of the tag can perform inside the <b>div</b>.
#             Special we use div to separte the sections like
#             <b>navbar, footer, body</b> in a webpage.</p>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <p style="padding: 15px;
#               color:white;background-color: #16A085 ;">👉
#          Final Output of advance html
# </p>

# %% [markdown]
# for html code: http://127.0.0.1:8000/cn/contacts
