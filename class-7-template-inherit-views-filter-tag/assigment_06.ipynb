# %% [markdown]
# <h1> Assignment-06 </h1>
#
# 1. Apply variables in your project.
# 2. How to works ‘Filter’? Use it.
# 3. Use template tag.
# 4. Create base.htm & do template inheritance.

# %% [markdown]
# <p style="padding: 10px;
#               color:white;background-color: #5642C5;">👉
#            Google Drive Link for project file
# <a href="https://drive.google.com/file/d/1BEKU18371yyWyH0qncEKvQ9pM-S6PDQW/view?usp=sharing" _blank"="" style="color:orange;" rel=" noreferrer nofollow"> Google Drive Link for project file </a>
#         </p>

# %% [markdown]
# <p style="padding: 10px;
#               color:white;background-color: #5642C5;">👉
#            How to create Project and Apps
# <a href="https://github.com/Shibli-Nomani/web-development-and-AI-with-Django/blob/main/class-05-create-django-project-and-apps/assignment_04.ipynb" _blank"="" style="color:orange;" rel=" noreferrer nofollow"> Create Project and Apps </a>
#         </p>

# %% [markdown]
# <p style="padding: 10px;
#               color:white;background-color: #5642C5;">👉
#            How to work on settings.py, views.py, urls.py, multiple apps, html templates
# <a href="https://github.com/Shibli-Nomani/web-development-and-AI-with-Django/blob/main/class-06-multiapps-template-render-include/assignment_05.ipynb" _blank"="" style="color:orange;" rel=" noreferrer nofollow"> for details</a>
#         </p>

# %% [markdown]
# <h2>Task-1: Variable</h2>
#
# a. http://127.0.0.1:8000/
#
# b. http://127.0.0.1:8000/at/blogs
#
# <h2>Task2: Variable and Filter</h2>
# a. http://127.0.0.1:8000/profiles/
# <h2>Task-3: Tag Condition</h2>
# a. http://127.0.0.1:8000/fl/flightdetails
# <h2>Task-4: Template Inheritance</h2>
# a. http://127.0.0.1:8000/profiles/

# %% [markdown]
# <h2> Django MVT(Model View Template) Architecture </h2>
#
# The MVT (Model View Template) is a software design pattern. It is a collection of three important components Model View and Template. The Model helps to handle database. It is a data access layer which handles the data.
#
# The Template is a presentation layer which handles User Interface part completely. The View is used to execute the business logic and interact with a model to carry data and renders a template.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <p style="padding: 10px;
#               color:white;background-color: #5642C5;">👉
#            One define function of views.py is for one url.
# </p>

# %% [markdown]
# <p style="padding: 10px;
#               color:white;background-color: #5642C5;">👉
#            Python: Select Interpreter(for virtual environment)
# </p>

# %% [markdown]
# ![image.png](data:image/png;base64,...)![image.png](data:image/png;base64,...)

# %% [markdown]
# <h2> Task-01: Variable </h2>
#
# `{{ variable_name }}`

# %% [markdown]
# project_name >> apps_name >> views.py

# %% [markdown]
# <p style="padding: 10px;
#               color:white;background-color: #5642C5;">👉
#            Add Variable in views.py
# </p>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <p style="padding: 10px;
#               color:white;background-color: #5642C5;">👉
#            Call variable in respective .html file
# </p>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <p style="padding: 15px;
#               color:white;background-color: #16A085 ;">👉
#          Final Output of variable
# </p>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <h2> Task-02: Filter </h2>
#
# Apply filter on variable for alteration(uppercase/lowercase) condition:
# `{{ variable_name | condition}}`

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <p style="padding: 15px;
#               color:white;background-color: #16A085 ;">👉
#          Final Output of variable and filter
# </p>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <h2> Task-02: Template Tagging </h2>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <p style="padding: 15px;
#               color:white;background-color: #16A085 ;">👉
#          Final Output of variable and filter
# </p>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <h2> Task-04: Template Inheritance(Base html file)</h2>
# Those html lines are common in every page, we can create common html file base.html. And we can call them by block for required position in each page. There can be multiple blocks in base.html
#
# `{%block title%} {%endblock title%}`
#
# inherit base.html to other page
# `{% extends common_code/base.html %}`
# note: common_code - base.html directory, base.html - common template

# %% [markdown]
# <p style="padding: 10px;
#               color:white;background-color: #5642C5;">👉
#            Create Title Block, Navigation Bar and Content Block
# </p>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <p style="padding: 10px;
#               color:white;background-color: #5642C5;">👉
#            inherit base.html to other page
# </p>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <p style="padding: 15px;
#               color:white;background-color: #16A085 ;">👉
#          Final Output of Template Inheritance
# </p>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
